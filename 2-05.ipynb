# %%
'abc'
# Out:
# 'abc'

# %%
"あいう"
# Out:
# 'あいう'

# %%
"I'm fine"
# Out:
# "I'm fine"

# %%
type('xyz')
# Out:
# str

# %%
zen_of_python
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e2e0508299e8> in <module>
# ----> 1 zen_of_python
#
# NameError: name 'zen_of_python' is not defined

# %%
print(zen_of_python)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-d0067d73599a> in <module>
# ----> 1 print(zen_of_python)
#
# NameError: name 'zen_of_python' is not defined

# %%
my_str = 'この後改行\nしてからタブ\tで空白。'
print(my_str)
# Out:
# この後改行
# してからタブ	で空白。

# %%
#これはコメント行です

print('a') #ここにも書けます。
# Out:
# a

# %%
print('a')
'''
これは、複数行のコメントです。
a
と
bの間
'''
print('b')
# Out:
# a
# b

# %%
'abc' + 'xyz'
# Out:
# 'abcxyz'

# %%
'repeat me!' * 3
# Out:
# 'repeat me!repeat me!repeat me!'

# %%
'abc' + 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-4ff1db6dfe0e> in <module>
# ----> 1 'abc' + 2
#
# TypeError: can only concatenate str (not "int") to str

# %%
'abc' + str(2)
# Out:
# 'abc2'

# %%
int('4')
# Out:
# 4

# %%
float('9.8')
# Out:
# 9.8

# %%
ord('あ')
# Out:
# 12354

# %%
chr(12354)
# Out:
# 'あ'

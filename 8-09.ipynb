# %%
0.1 * 3
# Out:
# 0.30000000000000004

# %%
0.1 * 3 == 0.3
# Out:
# False

# %%
from decimal import Decimal

# %%
d0 = Decimal('0.1')
print(d0, d0 * 3)
d0, d0 * 3
# Out:
# 0.1 0.3
# (Decimal('0.1'), Decimal('0.3'))

# %%
Decimal('0.1') * 3 == Decimal('0.3')
# Out:
# True

# %%
d1 = Decimal(0.1)
print(d1, d1 * 3)
d1, d1 * 3
# Out:
# 0.1000000000000000055511151231257827021181583404541015625 0.3000000000000000166533453694
# (Decimal('0.1000000000000000055511151231257827021181583404541015625'),
#  Decimal('0.3000000000000000166533453694'))

# %%
deci_pi = Decimal((0, (3, 1, 4), -2))
n_sqrt_2 = Decimal((1, (1, 4, 1, 4), -3))

print(deci_pi, n_sqrt_2)
deci_pi, n_sqrt_2
# Out:
# 3.14 -1.414
# (Decimal('3.14'), Decimal('-1.414'))

# %%
from decimal import Decimal, getcontext, FloatOperation

getcontext().traps[FloatOperation] = True

# %%
Decimal(0.1)
# Out:
# Decimal('0.1000000000000000055511151231257827021181583404541015625')

# %%
Decimal('1.300') + Decimal('1.200')
# Out:
# Decimal('2.500')

# %%
print(Decimal('1.300') + Decimal('1200'))
# Out:
# 1201.300

# %%
Decimal('1.3') * Decimal('1.2')
# Out:
# Decimal('1.56')

# %%
Decimal('1.30') * Decimal('1.20')
# Out:
# Decimal('1.5600')

# %%
from decimal import Decimal, getcontext
print(getcontext())
Decimal(1) / Decimal(7)
# Out:
# Context(prec=28, rounding=ROUND_HALF_EVEN, Emin=-999999, Emax=999999, capitals=1, clamp=0, flags=[], traps=[InvalidOperation, DivisionByZero, Overflow])
# Decimal('0.1428571428571428571428571429')

# %%
getcontext().prec = 6
Decimal(1) / Decimal(7)
# Out:
# Decimal('0.142857')

# %%
getcontext().prec = 42
Decimal(1) / Decimal(7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e3d62b24d369> in <module>
# ----> 1 getcontext().prec = 42
#       2 Decimal(1) / Decimal(7)
#
# NameError: name 'getcontext' is not defined

# %%
from decimal import ROUND_DOWN
decimal('7.325').quantize(Decimal('.01'), rounding=ROUND_DOWN)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-975dd346cc70> in <module>
#       1 from decimal import ROUND_DOWN
# ----> 2 decimal('7.325').quantize(Decimal('.01'), rounding=ROUND_DOWN)
#
# NameError: name 'decimal' is not defined

# %%
from decimal import ROUND_HALF_UP
Decimal('7.325').quantize(Decimal('.01'),rounding=ROUND_HALF_UP)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-6720408021a1> in <module>
#       1 from decimal import ROUND_HALF_UP
# ----> 2 Decimal('7.325').quantize(Decimal('.01'),rounding=ROUND_HALF_UP)
#
# NameError: name 'Decimal' is not defined

# %%
getcontext().prec = 28
Decimal('2').sqrt()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-31f6715b6f7f> in <module>
# ----> 1 getcontext().prec = 28
#       2 Decimal('2').sqrt()
#
# NameError: name 'getcontext' is not defined

# %%
Decimal('1').exp()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-d261e4f91f01> in <module>
# ----> 1 Decimal('1').exp()
#
# NameError: name 'Decimal' is not defined

# %%
Decimal('10').ln()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-b747f863d160> in <module>
# ----> 1 Decimal('10').ln()
#
# NameError: name 'Decimal' is not defined

# %%
Decimal('10').log10()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-8208656e1677> in <module>
# ----> 1 Decimal('10').log10()
#
# NameError: name 'Decimal' is not defined

# %%
diff = 100000000.2 - 1000000000
diff - 0.2
# Out:
# -900000000.0

# %%
diff_d = Decimal("10_000_000_000_2") - Decimal("10_000_000_000")
diff_d - Decimal("0.2")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-04ba87517b47> in <module>
# ----> 1 diff_d = Decimal("10_000_000_000_2") - Decimal("10_000_000_000")
#       2 diff_d - Decimal("0.2")
#
# NameError: name 'Decimal' is not defined

# %%
from decimal import Decimal
diff = 10000000000.2 - 10000000000
diff_d = Decimal("10000000000.2") - Decimal("10000000000")
print(diff)
print(diff_d)
# Out:
# 0.20000076293945312
# 0.2

# %%
a0 = 1.2 - 1.0
a0 - 0.2
# Out:
# -5.551115123125783e-17

# %%
a1 = 1000.2 - 1000.0
a1 - 0.2
# Out:
# 4.546363285840016e-14

# %%
a5 = 10_000_000_000.2 - 10_000_000_000
a5 - 0.2
# Out:
# 7.629394531138978e-07

# %%
a6 = 10_000_000_002.0 - 10_000_000_000.0
a6 - 2
# Out:
# 0.0

# %%
abc
100
f = open('sample.txt','r')
data = f.readline()
print(data)
f.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-66de8e4436fd> in <module>
# ----> 1 abc
#       2 100
#       3 f = open('sample.txt','r')
#       4 data = f.readline()
#       5 print(data)
#
# NameError: name 'abc' is not defined

# %%
with open('sample.txt','r') as f:
    data = f.readline()
    print(data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-a2ea130bc2c0> in <module>
# ----> 1 with open('sample.txt','r') as f:
#       2     data = f.readline()
#       3     print(data)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sample.txt'

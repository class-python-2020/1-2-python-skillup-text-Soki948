# %%
341
# Out:
# 341

# %%
2 + 3 * 4
# Out:
# 14

# %%
(2 + 3) * 4
# Out:
# 20

# %%
2 / 3
# Out:
# 0.6666666666666666

# %%
4 / 2
# Out:
# 2.0

# %%
2 // 3
# Out:
# 0

# %%
-2 // 3
# Out:
# -1

# %%
5 % 3
# Out:
# 2

# %%
2 ** 6
# Out:
# 64

# %%
2 ** 607 - 1
# Out:
# 531137992816767098689588206552468627329593117727031923199444138200403559860852242739162502265229285668889329486246501015346579337652707239409519978766587351943831270835393219031728127

# %%
341 % 253
# Out:
# 88

# %%
253 % 88
# Out:
# 77

# %%
88 % 77
# Out:
# 11

# %%
77 % 11
# Out:
# 0

# %%
import math
math.gcd(253,341)
# Out:
# 11

# %%
9 ** 22 % 23
# Out:
# 1

# %%
22 ** 22 % 23
# Out:
# 1

# %%
pow(9,22,23)
# Out:
# 1

# %%
a = 10

# %%
a * 2
# Out:
# 20

# %%
a
# Out:
# 10

# %%
a = a * 2
a
# Out:
# 20

# %%
a *= 2
a
# Out:
# 160

# %%
2a = 10
# Out:
#   File "<ipython-input-9-f5abf2455226>", line 1
#     2a = 10
#      ^
# SyntaxError: invalid syntax

# %%
for = 40
# Out:
#   File "<ipython-input-10-df55a543f4f2>", line 1
#     for = 40
#         ^
# SyntaxError: invalid syntax

# %%
1.2
# Out:
# 1.2

# %%
3.
# Out:
# 3.0

# %%
.6
# Out:
# 0.6

# %%
2e2
# Out:
# 200.0

# %%
3.2E3
# Out:
# 3200.0

# %%
import sys
sys.float_info.max
# Out:
# 1.7976931348623157e+308

# %%
sys.float_info.min
# Out:
# 2.2250738585072014e-308

# %%
1.0 == 0.5 + 0.5
# Out:
# True

# %%
0.3 == 0.1 + 0.1 + 0.1
# Out:
# False

# %%
from decimal import Decimal

# %%
Decimal.from_float(0.5)
# Out:
# Decimal('0.5')

# %%
Decimal.from_float(0.1)
# Out:
# Decimal('0.1000000000000000055511151231257827021181583404541015625')

# %%
Decimal.from_float(0.3)
# Out:
# Decimal('0.299999999999999988897769753748434595763683319091796875')

# %%
12/55
# Out:
# 0.21818181818181817

# %%
120//55
# Out:
# 2

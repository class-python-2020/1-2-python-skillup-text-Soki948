# %%
super_express = ['Nozomi3', 'Nozomi64', 'Nozomi150', 'Hikari440', 'Hikari538', 'Kodama730']

# %%
def splitter(value, sp):
    res = value.split(sp)
    if len(res) == 2:
        return (sp, int(res[1]))
    return None

result = []
for v in super_express:
    for s in ['Nozomi', 'Hikari', 'Kodama']:
        temp = splitter(v, s)
        if temp is not None:
            result.append(temp)

result
# Out:
# [('Nozomi', 3),
#  ('Nozomi', 64),
#  ('Nozomi', 150),
#  ('Hikari', 440),
#  ('Hikari', 538),
#  ('Kodama', 730)]

# %%
import re

result = []
for v in super_express:
    g = re.search(r'([a-zA-z]+)(/d+)',v)
    result.append((g.group(1), int(g.group(2))))

result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-732ea6c706c6> in <module>
#       2
#       3 result = []
# ----> 4 for v in super_express:
#       5     g = re.search(r'([a-zA-z]+)(/d+)',v)
#       6     result.append((g.group(1), int(g.group(2))))
#
# NameError: name 'super_express' is not defined

# %%
for v in super_express:
    g = re.search(r'([a-z]+)(\d+)', v)
    print(g.group(1), g.group(2), sep='/')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-dd69248ce64e> in <module>
# ----> 1 for v in super_express:
#       2     g = re.search(r'([a-z]+)(\d+)', v)
#       3     print(g.group(1), g.group(2), sep='/')
#
# NameError: name 'super_express' is not defined

# %%
for v in super_express:
    g = re.search(r'([^0-9]+)(\d+)', v)
    print(g.group(1), g.group(2), sep='/')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-14dfde710c05> in <module>
# ----> 1 for v in super_express:
#       2     g = re.search(r'([^0-9]+)(\d+)', v)
#       3     print(g.group(1), g.group(2), sep='/')
#
# NameError: name 'super_express' is not defined

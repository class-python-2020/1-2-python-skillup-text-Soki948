# %%
import math
math.pi
# Out:
# 3.141592653589793

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.inf
# Out:
# inf

# %%
type(math.inf)
# Out:
# float

# %%
math.nan
# Out:
# nan

# %%
type(math.nan)
# Out:
# float

# %%
math.inf == math.inf
# Out:
# True

# %%
math.nan == math.nan
# Out:
# False

# %%
math.isfinite(0.0)
# Out:
# True

# %%
math.isfinite(math.inf)
# Out:
# False

# %%
math.isfinite(math.nan)
# Out:
# False

# %%
math.isnan(math.nan)
# Out:
# True

# %%
math.isinf(math.inf)
# Out:
# True

# %%
a = 0.3
b = 0.1 + 0.1 + 0.1
a == b
# Out:
# False

# %%
math.isclose(a, b)
# Out:
# True

# %%
help(math.isclose)
# Out:
# Help on built-in function isclose in module math:
#
# isclose(a, b, *, rel_tol=1e-09, abs_tol=0.0)
#     Determine whether two floating point numbers are close in value.
#
#       rel_tol
#         maximum difference for being considered "close", relative to the
#         magnitude of the input values
#       abs_tol
#         maximum difference for being considered "close", regardless of the
#         magnitude of the input values
#
#     Return True if a is close in value to b, and False otherwise.
#
#     For the values to be considered close, the difference between them
#     must be smaller than at least one of the tolerances.
#
#     -inf, inf and NaN behave similarly to the IEEE 754 Standard.  That
#     is, NaN is not close to anything, even itself.  inf and -inf are
#     only close to themselves.

# %%
a = 0.0
b = 1 / pow(2, 53)
tol = 1 / pow(2, 50)
math.isclose(a, b, abs_tol=tol)
# Out:
# True

# %%
b = -1 / pow(2, 53)
math.isclose(a, b, abs_tol=tol)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-76145a21b9e2> in <module>
#       1 b = -1 / pow(2, 53)
# ----> 2 math.isclose(a, b, abs_tol=tol)
#
# NameError: name 'math' is not defined

# %%
import random

random.seed(85)

data = [round(ramdom.ramdom(),1) for i in range(15)]
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d727dee63ca5> in <module>
#       3 random.seed(85)
#       4
# ----> 5 data = [round(ramdom.ramdom(),1) for i in range(15)]
#       6 data
#
# <ipython-input-2-d727dee63ca5> in <listcomp>(.0)
#       3 random.seed(85)
#       4
# ----> 5 data = [round(ramdom.ramdom(),1) for i in range(15)]
#       6 data
#
# NameError: name 'ramdom' is not defined

# %%
sum(data) / len(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-6c186a541af1> in <module>
# ----> 1 sum(data) / len(data)
#
# NameError: name 'data' is not defined

# %%
import statistics
statistics.mean(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-a173fd7ddea8> in <module>
#       1 import statistics
# ----> 2 statistics.mean(data)
#
# NameError: name 'data' is not defined

# %%
statistics.median(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e9addda92e6b> in <module>
# ----> 1 statistics.median(data)
#
# NameError: name 'data' is not defined

# %%
statistics.mode(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-c2fb4b989cc7> in <module>
# ----> 1 statistics.mode(data)
#
# NameError: name 'data' is not defined

# %%
sorted(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-33bae22008f5> in <module>
# ----> 1 sorted(data)
#
# NameError: name 'data' is not defined

# %%
import math
import random

total = 0
num_inside = 0
sim_pi = 0
while not math.isclose(sim_pi, math_pi, abs_tol=1e-5):
    x = random.random()
    y = random.random()
    L = pow(x**2 + y**2, 0.5)
    total += 1
    if L <= 1:
        num_inside += 1
    sim_pi = 4 * num_inside / total
print(sim_pi)
print(total)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-f2b0786d661b> in <module>
#       5 num_inside = 0
#       6 sim_pi = 0
# ----> 7 while not math.isclose(sim_pi, math_pi, abs_tol=1e-5):
#       8     x = random.random()
#       9     y = random.random()
#
# NameError: name 'math_pi' is not defined

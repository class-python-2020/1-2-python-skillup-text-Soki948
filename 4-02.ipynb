# %%
def house_for_rent(bedrooms,walk_min,house_type,rent_yen):
    '''賃貸物件の特徴を受けとり、賃貸物件の特徴を辞書形式で返す関数'''
    return {'bedrooms':bedrooms,'walk_min':walk_min,
    'house_type':house_type,'rent_yen':rent_yen}
house_for_rent(2,15,'アパート',50)
# Out:
# {'bedrooms': 2, 'walk_min': 15, 'house_type': 'アパート', 'rent_yen': 50}

# %%
house_for_rent(2,'マンション',2,100)
# Out:
# {'bedrooms': 2, 'walk_min': 'マンション', 'house_type': 2, 'rent_yen': 100}

# %%
house_for_rent(rent_yen=100,walk_min=2,bedrooms=2,house_type='マンション')
# Out:
# {'bedrooms': 2, 'walk_min': 2, 'house_type': 'マンション', 'rent_yen': 100}

# %%
house_for_rent()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-b2c7062ef653> in <module>
# ----> 1 house_for_rent()
#
# TypeError: house_for_rent() missing 4 required positional arguments: 'bedrooms', 'walk_min', 'house_type', and 'rent_yen'

# %%
def house_for_rent(bedrooms=2,walk_min=6,house_type='アパート',
rent_yen=50):
    return {'bedrooms':bedrooms,'walk_min':walk_min,
            'house_type':house_type,'rent_yen':rent_yen}
house_for_rent()
# Out:
# {'bedrooms': 2, 'walk_min': 6, 'house_type': 'アパート', 'rent_yen': 50}

# %%
house_for_rent(5,house_type='マンション')
# Out:
# {'bedrooms': 5, 'walk_min': 6, 'house_type': 'マンション', 'rent_yen': 50}

# %%
house_for_rent(house_type='マンション',5)
# Out:
#   File "<ipython-input-7-f56259286c72>", line 1
#     house_for_rent(house_type='マンション',5)
#
# ^
# SyntaxError: positional argument follows keyword argument

# %%
house_for_rent(house_type='マンション',5)
# Out:
#   File "<ipython-input-8-f56259286c72>", line 1
#     house_for_rent(house_type='マンション',5)
#
# ^
# SyntaxError: positional argument follows keyword argument

# %%
p_list = perrin(100000)
x_list = list()
for n,p in enumerate(p_list):
    if n == 0:
        continue
    print((p,n),end=" ")
    if p % n == 0:
        x_list.append(n)

x_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-8e75a5490591> in <module>
# ----> 1 p_list = perrin(100000)
#       2 x_list = list()
#       3 for n,p in enumerate(p_list):
#       4     if n == 0:
#       5         continue
#
# NameError: name 'perrin' is not defined

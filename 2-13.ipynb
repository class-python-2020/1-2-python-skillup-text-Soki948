# %%
from random import randint
print(randint(0,10))
# Out:
# 8

# %%
from random import randint,choice
print(randint(0,10))
print(choice(['a','b','c']))
# Out:
# 0
# a

# %%
from  random import * 
print(randint(0,10))
# Out:
# 6

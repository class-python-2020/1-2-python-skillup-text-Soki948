# %%
for i in [0,1,2,3,4]:
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
my_list = [0,1,4,9,16,25,36]
for i in my_list:
    if i % 2 == 0:
        print(i)
# Out:
# 0
# 4
# 16
# 36

# %%
my_list = ['Tokyo','Osaka','Fukuoka','Aichi','Kyoto','Chiba',
'Saitama','Gunma']
my_list_6 =[]
for s in my_list:
    if len(s) >= 6:
        my_list_6.append(s)
print(s)
# Out:
# Gunma
